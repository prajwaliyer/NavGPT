# %%
from google.colab import auth
auth.authenticate_user()

# %%
import requests
print(requests.get('https://api.ipify.org').text)
# Out:
# 34.125.144.176

# %%
pip install youtube_transcript_api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-0.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from youtube_transcript_api) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->youtube_transcript_api) (1.26.15)
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-0.6.0

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
import googleapiclient.discovery
import json
from google.oauth2 import service_account
import google.auth.transport.requests


API_KEY = "AIzaSyC1_zGbMbTXTIkbK4ho0wgcEoaU8bQobH0"
ACCESS_TOKEN = "428637118276-8n95ohv3clke0hj3bdd4k5b7hgs72qr6.apps.googleusercontent.com"

credentials = service_account.Credentials.from_service_account_file("/content/youtubecaptions-384401-fe74ae73c098.json", scopes=["https://www.googleapis.com/auth/youtube.readonly","https://www.googleapis.com/auth/youtube.force-ssl"])

youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY, credentials=credentials)
session = google.auth.transport.requests.AuthorizedSession(credentials)

session.headers.update({'Authorization': 'Bearer ' + ACCESS_TOKEN})

search_response = youtube.search().list(
    q="machine learning videos",
    type="video",
    part="id,snippet",
    fields="items(id,snippet)",
    maxResults=10,
).execute()

# %%
transcript=[]
thumbnail=[]
for video_result in search_response["items"]:
    video_id = video_result["id"]["videoId"]
    try:
        transcript.append(YouTubeTranscriptApi.get_transcript(video_id))
        thumbnail.append(tn)
        #print(transcript)
    except:
        continue

# %%
#import pandas as pd
#t = pd.DataFrame(transcript)
#t
#thumbnail
len(thumbnail)
# Out:
# 10

# %%
fulltext = []

for i in range(len(transcript)):
  combined_text = ''
  for item in transcript[i]:
    combined_text += item['text'] + ' '
  fulltext.append([combined_text])

# %%
#fulltext

# %%
import pandas as pd
df_ft = pd.DataFrame(fulltext)
df_ft.columns=['Full Text']
df_ft.head()
# Out:
#                                            Full Text
# 0  we know humans learn from their past experienc...
# 1  our ability to learn and get better at tasks t...
# 2  This is Albert. He's an artificial intelligenc...
# 3  I'm sure you all agree\nthat machine learning ...
# 4  ever wondered how google translates an entire ...

# %%
def combine_text_by_duration(data, segment_duration):
    combined_text = []
    current_text = ""
    current_duration = 0
    for item in data:
  
        item_duration = item['duration']
        item_text = item['text']
        
        while item_duration > 0:
            dcd = segment_duration - current_duration
            if dcd == segment_duration:
                item_start = item['start']

            time_to_add = min(dcd, item_duration)
            current_text += item_text + ' '
            item_duration -= time_to_add
            current_duration += time_to_add
            
            if current_duration == segment_duration:
                combined_text.append({'text': current_text, 'start': item_start})
                fulltext.append(current_text)
                current_text = ""
                current_duration = 0
        
    return combined_text

# %%
y=[]
for i in range(len(transcript)):
  y.append(combine_text_by_duration(transcript[i],180))

# %%
df_parts = pd.DataFrame(y)
#df_parts.head()

# %%
#transcript[i]

# %%
import pandas as pd

# %%
data = {'Channel_title': [], 'Title': [], 'Link': [], 'Thumbnail': []}

for item in search_response["items"]:
    title = item['snippet']['title']
    channel_title = item['snippet']['channelTitle']
    video_link = "https://www.youtube.com/watch?v=" + item["id"]["videoId"]
    tn = video_result["snippet"]["thumbnails"]["high"]["url"]
    data['Link'].append(video_link)
    data['Title'].append(title)
    data['Channel_title'].append(channel_title)
    data['Thumbnail'].append(tn)
df = pd.DataFrame(data)

# %%
d = pd.concat([df,df_ft,df_parts],axis = 1)
d.head()
# Out:
#   Channel_title                                              Title  \
# 0   Simplilearn  Machine Learning Basics | What Is Machine Lear...
# 1  OxfordSparks                          What is Machine Learning?
# 2  AI Warehouse  AI Learns to Escape (Deep Reinforcement Learning)
# 3      edureka!  Machine Learning Full Course - Learn Machine L...
# 4   Simplilearn  Deep Learning In 5 Minutes | What Is Deep Lear...
#
#                                           Link  \
# 0  https://www.youtube.com/watch?v=ukzFI9rgwfU
# 1  https://www.youtube.com/watch?v=f_uwKZIAeM0
# 2  https://www.youtube.com/watch?v=v3UBlEJDXR0
# 3  https://www.youtube.com/watch?v=GwIo3gDZCVQ
# 4  https://www.youtube.com/watch?v=6M5VXKLf4D4
#
#                                           Thumbnail  \
# 0  https://i.ytimg.com/vi/5q87K1WaoFI/hqdefault.jpg
# 1  https://i.ytimg.com/vi/5q87K1WaoFI/hqdefault.jpg
# 2  https://i.ytimg.com/vi/5q87K1WaoFI/hqdefault.jpg
# 3  https://i.ytimg.com/vi/5q87K1WaoFI/hqdefault.jpg
# 4  https://i.ytimg.com/vi/5q87K1WaoFI/hqdefault.jpg
#
#                                            Full Text  \
# 0  we know humans learn from their past experienc...
# 1  our ability to learn and get better at tasks t...
# 2  This is Albert. He's an artificial intelligenc...
# 3  I'm sure you all agree\nthat machine learning ...
# 4  ever wondered how google translates an entire ...
#
#                                                    0  \
# 0  {'text': 'we know humans learn from their past...
# 1                                               None
# 2  {'text': 'This is Albert. He's an artificial i...
# 3  {'text': 'I'm sure you all agree
# that machine ...
# 4  {'text': 'ever wondered how google translates ...
#
#                                                    1  \
# 0  {'text': 'paul listens to a new song let's lab...
# 1                                               None
# 2                                               None
# 3  {'text': 'like they need to be program before ...
# 4  {'text': 'recognize the digits but what if a c...
#
#                                                    2  \
# 0  {'text': 'one dirham each coin has different w...
# 1                                               None
# 2                                               None
# 3  {'text': 'as they are many more factor
# and oth...
# 4  {'text': 'well-trained network so where is dee...
#
#                                                    3  \
# 0  {'text': 'unsupervised learning so we saw supe...
# 1                                               None
# 2                                               None
# 3  {'text': 'of machine learning is named
# as supe...
# 4                                               None
#
#                                                    4  ...  \
# 0  {'text': 'humongous data available everybody i...  ...
# 1                                               None  ...
# 2                                               None  ...
# 3  {'text': 'of a training data
# set do not have a...  ...
# 4                                               None  ...
#
#                                                  145  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'So as you can see here, we get Airli...
# 4                                               None
#
#                                                  146  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'in the description below and there a...
# 4                                               None
#
#                                                  147  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'The framework is based
# on tensorflow...
# 4                                               None
#
#                                                  148  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'who do not understand
# the theory at ...
# 4                                               None
#
#                                                  149  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'and potential challenges
# that need s...
# 4                                               None
#
#                                                  150  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'But what if the machine started lear...
# 4                                               None
#
#                                                  151  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'we have like three thousand dollars ...
# 4                                               None
#
#                                                  152  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'to study and transform
# data science ...
# 4                                               None
#
#                                                  153  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'So you'll need to be
# intimately fami...
# 4                                               None
#
#                                                  154
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'text': 'All those technical
# skills cannot be...
# 4                                               None
#
# [5 rows x 160 columns]

# %%
search_response[]
# Out:
# {'items': [{'id': {'kind': 'youtube#video', 'videoId': 'ukzFI9rgwfU'},
#    'snippet': {'publishedAt': '2018-09-19T14:57:02Z',
#     'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg',
#     'title': 'Machine Learning Basics | What Is Machine Learning? | Introduction To Machine Learning | Simplilearn',
#     'description': 'Artificial Intelligence Engineer Program (Discount Coupon: YTBE15): ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ukzFI9rgwfU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ukzFI9rgwfU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ukzFI9rgwfU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Simplilearn',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-09-19T14:57:02Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': 'f_uwKZIAeM0'},
#    'snippet': {'publishedAt': '2017-01-11T08:24:20Z',
#     'channelId': 'UCY5NDinr2975LghozXAeTWQ',
#     'title': 'What is Machine Learning?',
#     'description': 'Machine learning is all around us; on our phones, powering social networks, helping the police and doctors, scientists and mayors ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f_uwKZIAeM0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f_uwKZIAeM0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f_uwKZIAeM0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'OxfordSparks',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-01-11T08:24:20Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': 'v3UBlEJDXR0'},
#    'snippet': {'publishedAt': '2022-10-29T21:36:34Z',
#     'channelId': 'UCMT1Aw4R4nf_sFNDeuJqc6w',
#     'title': 'AI Learns to Escape (Deep Reinforcement Learning)',
#     'description': "AI Teaches Itself How to Escape! In this video an AI named Albert learns how to escape 5 rooms I've designed. The AI was trained ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/v3UBlEJDXR0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/v3UBlEJDXR0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/v3UBlEJDXR0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'AI Warehouse',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-29T21:36:34Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': 'GwIo3gDZCVQ'},
#    'snippet': {'publishedAt': '2019-09-22T08:30:00Z',
#     'channelId': 'UCkw4JCwteGrDHIsyIIKo4tQ',
#     'title': 'Machine Learning Full Course - Learn Machine Learning 10 Hours | Machine Learning Tutorial | Edureka',
#     'description': 'Machine Learning Engineer Masters Program (Use Code "YOUTUBE20"): ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GwIo3gDZCVQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GwIo3gDZCVQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GwIo3gDZCVQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'edureka!',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-09-22T08:30:00Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': '6M5VXKLf4D4'},
#    'snippet': {'publishedAt': '2019-06-03T14:30:00Z',
#     'channelId': 'UCsvqVGtbbyHaMoevxPAq9Fg',
#     'title': 'Deep Learning In 5 Minutes | What Is Deep Learning? | Deep Learning Explained Simply | Simplilearn',
#     'description': 'Artificial Intelligence Engineer Program (Discount Coupon: YTBE15): ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6M5VXKLf4D4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6M5VXKLf4D4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6M5VXKLf4D4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Simplilearn',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-06-03T14:30:00Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': 'SX08NT55YhA'},
#    'snippet': {'publishedAt': '2022-03-12T15:00:22Z',
#     'channelId': 'UCh1zLfuN6F_X4eoNKCsyICA',
#     'title': 'A.I. Learns to Drive From Scratch in Trackmania',
#     'description': 'I made an A.I. that teaches itself to drive in the racing game Trackmania, using Machine-Learning. I used Deep-Q-Learning, ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SX08NT55YhA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SX08NT55YhA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SX08NT55YhA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Yosh',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-12T15:00:22Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': 'yN7ypxC7838'},
#    'snippet': {'publishedAt': '2020-05-16T01:59:09Z',
#     'channelId': 'UCF-uUxo43IPpnEwnR62WGlA',
#     'title': 'All Machine Learning Models Explained in 5 Minutes | Types of ML Models Basics',
#     'description': 'Confused about understanding machine learning models? Well, this video will help you grab the basics of each one of them.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yN7ypxC7838/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yN7ypxC7838/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yN7ypxC7838/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Learn with Whiteboard',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-05-16T01:59:09Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': 'QghjaS0WQQU'},
#    'snippet': {'publishedAt': '2018-02-22T16:18:06Z',
#     'channelId': 'UCeYUHG6o0YguM-g23htdsSw',
#     'title': 'What is Machine Learning?',
#     'description': "In this video, you'll learn more about the evolution of machine learning and its impact on daily life.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QghjaS0WQQU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QghjaS0WQQU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QghjaS0WQQU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'GCFLearnFree',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2018-02-22T16:18:06Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': 'qv6UVOQ0F44'},
#    'snippet': {'publishedAt': '2015-06-13T19:00:01Z',
#     'channelId': 'UC8aG3LDTDwNR1UQhSn9uVrw',
#     'title': 'MarI/O - Machine Learning for Video Games',
#     'description': 'MarI/O is a program made of neural networks and genetic algorithms that kicks butt at Super Mario World. Source Code: ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qv6UVOQ0F44/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qv6UVOQ0F44/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qv6UVOQ0F44/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'SethBling',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2015-06-13T19:00:01Z'}},
#   {'id': {'kind': 'youtube#video', 'videoId': '5q87K1WaoFI'},
#    'snippet': {'publishedAt': '2021-08-18T16:00:08Z',
#     'channelId': 'UCftwRNsjfRo08xYE31tkiyw',
#     'title': 'Computer Scientist Explains Machine Learning in 5 Levels of Difficulty | WIRED',
#     'description': 'WIRED has challenged computer scientist and Hidden Door cofounder and CEO Hilary Mason to explain machine learning to 5 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5q87K1WaoFI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5q87K1WaoFI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5q87K1WaoFI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'WIRED',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-18T16:00:08Z'}}]}
